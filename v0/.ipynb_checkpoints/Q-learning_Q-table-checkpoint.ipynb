# %%
import numpy as np
import sys
from six import StringIO, b

from gym import utils
from gym.envs.toy_text import discrete

LEFT = 0
DOWN = 1
RIGHT = 2
UP = 3

MAPS = {
    "4x4": [
        "SFFF",
        "FHFH",
        "FFFH",
        "HFFG"
    ],
    "8x8": [
        "SFFFFFFF",
        "FFFFFFFF",
        "FFFHFFFF",
        "FFFFFHFF",
        "FFFHFFFF",
        "FHHFFFHF",
        "FHFFHFHF",
        "FFFHFFFG"
    ],
}

class FrozenLakeEnv(discrete.DiscreteEnv):
    """
    Winter is here. You and your friends were tossing around a frisbee at the park
    when you made a wild throw that left the frisbee out in the middle of the lake.
    The water is mostly frozen, but there are a few holes where the ice has melted.
    If you step into one of those holes, you'll fall into the freezing water.
    At this time, there's an international frisbee shortage, so it's absolutely imperative that
    you navigate across the lake and retrieve the disc.
    However, the ice is slippery, so you won't always move in the direction you intend.
    The surface is described using a grid like the following
        SFFF
        FHFH
        FFFH
        HFFG
    S : starting point, safe
    F : frozen surface, safe
    H : hole, fall to your doom
    G : goal, where the frisbee is located
    The episode ends when you reach the goal or fall in a hole.
    You receive a reward of 1 if you reach the goal, and zero otherwise.
    """

    metadata = {'render.modes': ['human', 'ansi']}

    def __init__(self, desc=None, map_name="4x4",is_slippery=True):
        if desc is None and map_name is None:
            raise ValueError('Must provide either desc or map_name')
        elif desc is None:
            desc = MAPS[map_name]
        self.desc = desc = np.asarray(desc,dtype='c')
        self.nrow, self.ncol = nrow, ncol = desc.shape
        self.reward_range = (0, 1)

        nA = 4
        nS = nrow * ncol

        isd = np.array(desc == b'S').astype('float64').ravel()
        isd /= isd.sum()

        P = {s : {a : [] for a in range(nA)} for s in range(nS)}

        def to_s(row, col):
            return row*ncol + col
        
        def inc(row, col, a):
            if a==0: # left
                col = max(col-1,0)
            elif a==1: # down
                row = min(row+1,nrow-1)
            elif a==2: # right
                col = min(col+1,ncol-1)
            elif a==3: # up
                row = max(row-1,0)
            return (row, col)

        for row in range(nrow):
            for col in range(ncol):
                s = to_s(row, col)
                for a in range(4):
                    li = P[s][a]
                    letter = desc[row, col]
                    if letter in b'GH':
                        li.append((1.0, s, 0, True))
                    else:
                        if is_slippery:
                            for b in [(a-1)%4, a, (a+1)%4]:
                                newrow, newcol = inc(row, col, b)
                                newstate = to_s(newrow, newcol)
                                newletter = desc[newrow, newcol]
                                done = bytes(newletter) in b'GH'
                                rew = float(newletter == b'G')
                                li.append((1.0/3.0, newstate, rew, done))
                        else:
                            newrow, newcol = inc(row, col, a)
                            newstate = to_s(newrow, newcol)
                            newletter = desc[newrow, newcol]
                            done = bytes(newletter) in b'GH'
                            rew = float(newletter == b'G')
                            li.append((1.0, newstate, rew, done))

        super(FrozenLakeEnv, self).__init__(nS, nA, P, isd)

    def render(self, mode='human'):
        outfile = StringIO() if mode == 'ansi' else sys.stdout

        row, col = self.s // self.ncol, self.s % self.ncol
        desc = self.desc.tolist()
        desc = [[c.decode('utf-8') for c in line] for line in desc]
        desc[row][col] = utils.colorize(desc[row][col], "red", highlight=True)
        if self.lastaction is not None:
            outfile.write("  ({})\n".format(["Left","Down","Right","Up"][self.lastaction]))
        else:
            outfile.write("\n")
        outfile.write("\n".join(''.join(line) for line in desc)+"\n")

        if mode != 'human':
            return outfile

# %%
vector = [3, 2, 3, 3]
x = np.max(vector)
indices = np.nonzero(vector == x)[0] # 인덱스 자체가 랜덤 방향이 되므로.
import random
random.choice(indices)
# Out:
# 3

# %%
import gym
import random as rand
import numpy as np

env = gym.make('FrozenLake-v0')

LEFT = 0
DOWN = 1
RIGHT = 2
UP = 3

Q = np.zeros([env.observation_space.n,env.action_space.n])
# Q[0,RIGHT] = 1
# Q[1,RIGHT] = 1
# Q[2,DOWN] = 1
# Q[6,DOWN] = 1
# Q[10,DOWN] = 1
# Q[14,RIGHT] = 1
# print(Q)

def greedy_action(vector):
    m = np.amax(vector)
    indices = np.nonzero(vector == m)[0]
    return random.choice(indices)

def random_action():
    dirs = [ LEFT, DOWN, RIGHT, UP ]
    return rand.choice(dirs)

exit = False

for step in range(100):
    if exit: break
    prev_state = env.reset()
    curr_state = prev_state
    doomed = False
    state_list = []
    while not doomed or not exit:
        state_list.append(prev_state)
        action = greedy_action(Q[prev_state,:]) # random_action()
        curr_state, reward, doomed, _ = env.step(0) 
        if not doomed and prev_state != curr_state:
            env.render()
            print("[ING.][%d][%d->%d] : %f" % (step, prev_state, curr_state, reward))
        if doomed:
            env.render()
            print("[FAIL][%d][%d->%d] : %f\n" % (step, prev_state, curr_state, reward))
        elif reward == 1:
            env.render()
            print("[SUCC][%d][%d->%d] : %f" % (step, prev_state, curr_state, reward))
#         Q[prev_state, action] = reward + np.max(Q[curr_state,:])
            exit = True
        prev_state = curr_state
print("EOF")
# Out:
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][0][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][0][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][1][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][1][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][1][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][2][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][2][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][3][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][3][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][3][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][3][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][3][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][4][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][4][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][4][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][4][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][4][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][5][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][5][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][5][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][6][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][6][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][7][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][7][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][8][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][8][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][9][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][9][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][10][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][10][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][10][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][10][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][10][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][11][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][11][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][12][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][12][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][13][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][13][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][14][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][14][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][15][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][15][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][16][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][16][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][17][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][17][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][18][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][18][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][19][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][19][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][20][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][20][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][21][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][21][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][22][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][22][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][22][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][23][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][23][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][23][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][24][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][24][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][25][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][25][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][26][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][26][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][27][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][27][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][27][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][28][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][28][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][28][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][28][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][28][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][29][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][29][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][29][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][29][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][29][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][30][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][30][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][30][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][31][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][31][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][32][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][32][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][33][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][33][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][34][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][34][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][35][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][35][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][36][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][36][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][37][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][37][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][37][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][38][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][38][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][38][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][39][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][39][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][40][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][40][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][41][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][41][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][42][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][42][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][43][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][43][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][44][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][44][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][44][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][45][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][45][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][46][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][46][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][46][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][47][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][47][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][47][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][48][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][48][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][49][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][49][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][49][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][50][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][50][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][51][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][51][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][52][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][52][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][53][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][53][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][54][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][54][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][54][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][55][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][55][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][55][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][56][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][56][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][57][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][57][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][58][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][58][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][59][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][59][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][60][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][60][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][61][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][61][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][61][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][62][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][62][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][63][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][63][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][63][8->12] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][64][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][64][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][65][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][65][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][66][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][66][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][66][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][67][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][67][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][67][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][67][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][67][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][68][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][68][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][68][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][69][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][69][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][70][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][70][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][70][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][70][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][70][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][71][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][71][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][71][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][71][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][71][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][72][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][72][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][72][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][73][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][73][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][74][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][74][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][74][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][75][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][75][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][75][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][76][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][76][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][76][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][77][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][77][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][78][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][78][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][79][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][79][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][79][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][80][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][80][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][80][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][80][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][80][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][81][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][81][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][82][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][82][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][82][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][82][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][82][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][83][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][83][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][84][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][84][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][85][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][85][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][86][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][86][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][86][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][87][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][87][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][87][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][87][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][87][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][88][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][88][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][88][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][89][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][89][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][90][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][90][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][90][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][90][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][90][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][91][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][91][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][92][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][92][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][93][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][93][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][94][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][94][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][95][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][95][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][96][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][96][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][97][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][97][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][97][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][98][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][98][8->12] : 0.000000
#
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][8->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->0] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][0->4] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [ING.][99][4->8] : 0.000000
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# [FAIL][99][8->12] : 0.000000
#
# EOF
